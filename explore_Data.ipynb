# %%
import pandas as pd

# %%
try:
    df = pd.read_csv('amazon_product.csv', index_col=0)
except FileNotFoundError:
    raise FileNotFoundError("Path is not valid")

# %%
df.head()
# Out:
#          asin                                      product_title  \
# 0  B0BQ118F2T  Moto G Play 2023 3-Day Battery Unlocked Made f...
# 1  B0CTD47P22  SAMSUNG Galaxy A15 5G (SM-156M/DSN), 128GB 6GB...
# 2  B0CHH6X6H2  Total by Verizon | Samsung Galaxy A03s | Locke...
# 3  B0BZ9XNBRB  Google Pixel 7a - Unlocked Android Cell Phone ...
# 4  B0CN1QSH8Q  SAMSUNG Galaxy A15 5G A Series Cell Phone, 128...
#
#   product_price product_original_price currency  product_star_rating  \
# 0        $99.99                $169.99      USD                  4.0
# 1       $149.74                $158.00      USD                  4.2
# 2        $49.88                    NaN      USD                  3.9
# 3       $335.00                $499.00      USD                  4.3
# 4       $199.99                    NaN      USD                  4.1
#
#    product_num_ratings                           product_url  \
# 0                 2929  https://www.amazon.com/dp/B0BQ118F2T
# ...

# %%
df.shape
# Out:
# (64, 21)

# %%
df.columns
# Out:
# Index(['asin', 'product_title', 'product_price', 'product_original_price',
#        'currency', 'product_star_rating', 'product_num_ratings', 'product_url',
#        'product_photo', 'product_num_offers', 'product_minimum_offer_price',
#        'is_best_seller', 'is_amazon_choice', 'is_prime',
#        'climate_pledge_friendly', 'sales_volume', 'delivery', 'has_variations',
#        'product_availability', 'unit_price', 'unit_count'],
#       dtype='str')

# %%
len(df)
# Out:
# 64

# %%
df.dtypes
# Out:
# asin                               str
# product_title                      str
# product_price                      str
# product_original_price             str
# currency                           str
# product_star_rating            float64
# product_num_ratings              int64
# product_url                        str
# product_photo                      str
# product_num_offers               int64
# product_minimum_offer_price        str
# is_best_seller                    bool
# is_amazon_choice                  bool
# is_prime                          bool
# climate_pledge_friendly           bool
# sales_volume                       str
# delivery                           str
# has_variations                    bool
# product_availability               str
# unit_price                         str
# unit_count                     float64
# dtype: object

# %%
# Keep an untouched copy of the raw data before changing any dtypes
df_raw = df.copy()

# %%
price_cols = ['product_price', 'product_original_price', 'product_minimum_offer_price', 'unit_price']
for col in price_cols:
    df[col] = df[col].str.replace('$', '', regex=False).astype(float)


df.dtypes
# Out:
# asin                               str
# product_title                      str
# product_price                  float64
# product_original_price         float64
# currency                           str
# product_star_rating            float64
# product_num_ratings              int64
# product_url                        str
# product_photo                      str
# product_num_offers               int64
# product_minimum_offer_price    float64
# is_best_seller                    bool
# is_amazon_choice                  bool
# is_prime                          bool
# climate_pledge_friendly           bool
# sales_volume                       str
# delivery                           str
# has_variations                    bool
# product_availability               str
# unit_price                     float64
# unit_count                     float64
# dtype: object

# %%
df['sales_volume']
# Out:
# 0      6K+ bought in past month
# 1      3K+ bought in past month
# 2      2K+ bought in past month
# 3     10K+ bought in past month
# 4      3K+ bought in past month
#                 ...
# 59     50+ bought in past month
# 60           Print List Price:
# 61                  Jul 7, 2023
# 62                 Aug 13, 2024
# 63    80K+ bought in past month
# Name: sales_volume, Length: 64, dtype: str

# %%
df2 = pd.read_csv("amazon_product_clean.csv")

# %%
df2.dtypes
# Out:
# asin                               str
# product_title                      str
# product_price                  float64
# product_original_price         float64
# currency                           str
# product_star_rating            float64
# product_num_ratings              int64
# product_url                        str
# product_photo                      str
# product_num_offers               int64
# product_minimum_offer_price    float64
# is_best_seller                    bool
# is_amazon_choice                  bool
# is_prime                          bool
# climate_pledge_friendly           bool
# sales_volume                       str
# delivery                           str
# has_variations                    bool
# product_availability               str
# unit_price                     float64
# unit_count                     float64
# dtype: object

# %%
df["product_price"]
# Out:
# 0      99.99
# 1     149.74
# 2      49.88
# 3     335.00
# 4     199.99
#        ...
# 59     34.98
# 60     14.99
# 61      0.00
# 62     69.99
# 63     59.99
# Name: product_price, Length: 64, dtype: float64

# %%
df["product_price"] <= 50
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
#       ...
# 59     True
# 60     True
# 61     True
# 62    False
# 63    False
# Name: product_price, Length: 64, dtype: bool

# %%
df['product_star_rating'].sort_values().head(5)
# Out:
# 42    1.8
# 62    2.6
# 36    3.2
# 49    3.2
# 61    3.5
# Name: product_star_rating, dtype: float64

# %%
df.sort_values('product_star_rating', ascending=False).head(5)
# Out:
#           asin                                      product_title  \
# 20  B0CRB1VZ46  Amazon Basics Multipurpose, Comfort Grip, PVD ...
# 19  B0CRDYZVDC  Amazon Basics Heavy Duty Plastic Folders with ...
# 37  B0CV4FQPY1  Bounty Select-A-Size Paper Towels, White, 8 Tr...
# 31  B07RFSSYBH  Atomic Habits: An Easy &amp; Proven Way to Bui...
# 17  B0D54JZTHY                                Apple AirTag 4 pack
#
#     product_price  product_original_price currency  product_star_rating  \
# 20           2.39                     NaN      USD                  4.8
# 19           0.49                     NaN      USD                  4.8
# 37          22.18                     NaN      USD                  4.8
# 31           0.00                    18.0      USD                  4.8
# 17          84.99                    99.0      USD                  4.7
#
#     product_num_ratings                           product_url  \
# 20                54922  https://www.amazon.com/dp/B0CRB1VZ46
# ...

# %%
df.sort_values('product_num_ratings', ascending=False).head(5)
# Out:
#           asin    product_title  product_price  product_original_price  \
# 55  B07Y8SJGCV          Disney+            0.0                     NaN
# 56  B005ZXWMUS          Netflix            0.0                     NaN
# 23  B08BG9MPT9       Peacock TV            0.0                     NaN
# 43  B00XZFCVK4              Max            0.0                     NaN
# 45  B01GGU0XWC  It Ends with Us            0.0                   20.24
#
#    currency  product_star_rating  product_num_ratings  \
# 55      USD                  4.4              1015448
# 56      USD                  4.6               447888
# 23      USD                  4.2               437768
# 43      USD                  4.3               384756
# 45      USD                  4.7               333273
#
#                              product_url  \
# 55  https://www.amazon.com/dp/B07Y8SJGCV
# 56  https://www.amazon.com/dp/B005ZXWMUS
# 23  https://www.amazon.com/dp/B08BG9MPT9
# ...

# %%
df['product_title'][0]
# Out:
# 'Moto G Play 2023 3-Day Battery Unlocked Made for US 3/32GB 16MP Camera Navy Blue'

# %%
df[df['is_best_seller'] == True]
# Out:
#           asin                                      product_title  \
# 11  B086QB7WZ1  AT&amp;T BL102-2 DECT 6.0 2-Handset Cordless P...
# 19  B0CRDYZVDC  Amazon Basics Heavy Duty Plastic Folders with ...
# 20  B0CRB1VZ46  Amazon Basics Multipurpose, Comfort Grip, PVD ...
# 21  1368092209                   The Book of Bill (Gravity Falls)
# 22  1649374186  Onyx Storm (Deluxe Limited Edition) (The Empyr...
# 24  B0DBD2L1NN  Thanksgiving - UHD/BD Combo + Digital + Steelb...
# 25  B0CS12LZLS  NESCAFÉ Gold Espresso Blonde, Instant Coffee, ...
# 26  0062300555  Hillbilly Elegy: A Memoir of a Family and Cult...
# 27  B0DBR4KDRF              FOREVER (Amazon Exclusive Blue Vinyl)
# 29  B0D5FZGY8W  URO Vaginal Probiotics for Women pH Balance wi...
# 31  B07RFSSYBH  Atomic Habits: An Easy &amp; Proven Way to Bui...
# 33  B0C9N2L56X  The Anxious Generation: How the Great Rewiring...
# 39  052802759X           Rand McNally Large Scale Road Atlas 2025
# ...
